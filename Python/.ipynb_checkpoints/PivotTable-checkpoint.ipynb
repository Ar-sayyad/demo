# %%
import pandas as pd
df = pd.read_csv("humidity.csv")
df
# Out:
#           date      city  temperature  humidity
# 0   01-01-2019  new york           32        56
# 1   01-02-2019  new york           35        58
# 2   01-04-2019  new york           36        52
# 3   01-05-2019    mumbai           33        55
# 4   01-06-2019    mumbai           36        60
# 5   01-07-2019    mumbai           36        59
# 6   01-08-2019    mumbai           25        85
# 7   01-09-2019     paris           34        75
# 8   01-10-2019     paris           33        70
# 9   01-11-2019     paris           42        68
# 10  01-12-2019     paris           45        35

# %%
df.pivot(index="date",columns="city")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-df847602f8d8> in <module>
# ----> 1 df.pivot(index="date",columns="city")
#
# c:\users\baps\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    5626     def pivot(self, index=None, columns=None, values=None):
#    5627         from pandas.core.reshape.pivot import pivot
# -> 5628         return pivot(self, index=index, columns=columns, values=values)
#    5629
#    5630     _shared_docs['pivot_table'] = """
#
# c:\users\baps\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     386             indexed = data._constructor_sliced(data[values].values,
#     387                                                index=index)
# --> 388     return indexed.unstack(columns)
#     389
#     390
#
# c:\users\baps\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in unstack(self, level, fill_value)
#    5990         """
#    5991         from pandas.core.reshape.reshape import unstack
# -> 5992         return unstack(self, level, fill_value)
#    5993
#    5994     _shared_docs['melt'] = ("""
#
# c:\users\baps\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     386     if isinstance(obj, DataFrame):
#     387         if isinstance(obj.index, MultiIndex):
# --> 388             return _unstack_frame(obj, level, fill_value=fill_value)
#     389         else:
#     390             return obj.T.stack(dropna=False)
#
# c:\users\baps\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\reshape\reshape.py in _unstack_frame(obj, level, fill_value)
#     409                                value_columns=obj.columns,
#     410                                fill_value=fill_value,
# --> 411                                constructor=obj._constructor)
#     412         return unstacker.get_result()
#     413
#
# c:\users\baps\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\reshape\reshape.py in __init__(self, values, index, level, value_columns, fill_value, constructor)
#     126
#     127         self._make_sorted_values_labels()
# --> 128         self._make_selectors()
#     129
#     130     def _make_sorted_values_labels(self):
#
# c:\users\baps\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\reshape\reshape.py in _make_selectors(self)
#     164
#     165         if mask.sum() < len(self.index):
# --> 166             raise ValueError('Index contains duplicate entries, '
#     167                              'cannot reshape')
#     168
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
df.pivot(index="date",columns="city", values="humidity")
# Out:
# city        mumbai  new york  paris
# date
# 01-01-2019     NaN      56.0    NaN
# 01-02-2019     NaN      58.0    NaN
# 01-04-2019     NaN      52.0    NaN
# 01-05-2019    55.0       NaN    NaN
# 01-06-2019    60.0       NaN    NaN
# 01-07-2019    59.0       NaN    NaN
# 01-08-2019    85.0       NaN    NaN
# 01-09-2019     NaN       NaN   75.0
# 01-10-2019     NaN       NaN   70.0
# 01-11-2019     NaN       NaN   68.0
# 01-12-2019     NaN       NaN   35.0

# %%
df = pd.read_csv("humidity1.csv")
df
# Out:
#          date      city  temperature  humidity
# 0  01-01-2019  new york           32        56
# 1  01-01-2019  new york           35        58
# 2  01-02-2019  new york           38        60
# 3  01-02-2019  new york           41        62
# 4  01-01-2019    mumbai           44        64
# 5  01-01-2019    mumbai           47        66
# 6  01-02-2019    mumbai           50        68
# 7  01-02-2019    mumbai           53        70

# %%
df.pivot_table(index="city",columns="date")
# Out:
#            humidity            temperature
# date     01-01-2019 01-02-2019  01-01-2019 01-02-2019
# city
# mumbai           65         69        45.5       51.5
# new york         57         61        33.5       39.5

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px solid gray;
#     text-align:left;
# }
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px solid gray;
#     text-align:left;
# }

# %%
df.pivot_table(index="city",columns="date", aggfunc="sum")
# Out:
#            humidity            temperature
# date     01-01-2019 01-02-2019  01-01-2019 01-02-2019
# city
# mumbai          130        138          91        103
# new york        114        122          67         79

# %%
df.pivot_table(index="city",columns="date", aggfunc="count")
# Out:
#            humidity            temperature
# date     01-01-2019 01-02-2019  01-01-2019 01-02-2019
# city
# mumbai            2          2           2          2
# new york          2          2           2          2

# %%
df.pivot_table(index="city",columns="date", margins=True)
# Out:
#            humidity                  temperature
# date     01-01-2019 01-02-2019   All  01-01-2019 01-02-2019   All
# city
# mumbai           65         69  67.0        45.5       51.5  48.5
# new york         57         61  59.0        33.5       39.5  36.5
# All              61         65  63.0        39.5       45.5  42.5

# %%
df = pd.read_csv("humidity2.csv")
df
# Out:
#          date      city  temperature  humidity
# 0  01-01-2019  new york           32        56
# 1  01-02-2019  new york           35        58
# 2  01-03-2019  new york           38        60
# 3  02-01-2019  new york           41        62
# 4  02-02-2019  new york           44        64
# 5  02-03-2019  new york           47        66

# %%
df['date']=pd.to_datetime(df['date'])
df
# Out:
#         date      city  temperature  humidity
# 0 2019-01-01  new york           32        56
# 1 2019-01-02  new york           35        58
# 2 2019-01-03  new york           38        60
# 3 2019-02-01  new york           41        62
# 4 2019-02-02  new york           44        64
# 5 2019-02-03  new york           47        66

# %%
type(df['date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city')
# Out:
#            humidity temperature
# city       new york    new york
# date
# 2019-01-31       58          35
# 2019-02-28       64          44
