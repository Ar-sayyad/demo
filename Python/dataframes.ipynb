# %%
import pandas as pd
data = {
    'Day': ['1/1/2019','1/2/2019','1/3/2019','1/4/2019','1/5/2019','1/6/2019','1/7/2019'],
    'Temperature': [32,35,28,34,31,36,30],
    'Windspeed': [6,8,7,4,2,5,9],
    'Events': ['Rain','Sunny','Snow','Snow','Rain','Rain','Sunny']
}
#df = pd.read_csv("D:\\files\\mydata.csv")
df = pd.DataFrame(data)
df
# Out:
#         Day  Temperature  Windspeed Events
# 0  1/1/2019           32          6   Rain
# 1  1/2/2019           35          8  Sunny
# 2  1/3/2019           28          7   Snow
# 3  1/4/2019           34          4   Snow
# 4  1/5/2019           31          2   Rain
# 5  1/6/2019           36          5   Rain
# 6  1/7/2019           30          9  Sunny

# %%
rows, columns = df.shape

# %%
rows
# Out:
# 7

# %%
columns
# Out:
# 4

# %%
df.head(2)
# Out:
#         Day  Temperature  Windspeed Events
# 0  1/1/2019           32          6   Rain
# 1  1/2/2019           35          8  Sunny

# %%
df.tail(3)
# Out:
#         Day  Temperature  Windspeed Events
# 4  1/5/2019           31          2   Rain
# 5  1/6/2019           36          5   Rain
# 6  1/7/2019           30          9  Sunny

# %%
df[2:5]
# Out:
#         Day  Temperature  Windspeed Events
# 2  1/3/2019           28          7   Snow
# 3  1/4/2019           34          4   Snow
# 4  1/5/2019           31          2   Rain

# %%
df[:]
# Out:
#         Day  Temperature  Windspeed Events
# 0  1/1/2019           32          6   Rain
# 1  1/2/2019           35          8  Sunny
# 2  1/3/2019           28          7   Snow
# 3  1/4/2019           34          4   Snow
# 4  1/5/2019           31          2   Rain
# 5  1/6/2019           36          5   Rain
# 6  1/7/2019           30          9  Sunny

# %%
df.columns
# Out:
# Index(['Day', 'Temperature', 'Windspeed', 'Events'], dtype='object')

# %%
df.Day
# Out:
# 0    1/1/2019
# 1    1/2/2019
# 2    1/3/2019
# 3    1/4/2019
# 4    1/5/2019
# 5    1/6/2019
# 6    1/7/2019
# Name: Day, dtype: object

# %%
df.Events
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5     Rain
# 6    Sunny
# Name: Events, dtype: object

# %%
type(df['Events'])
# Out:
# pandas.core.series.Series

# %%
df[['Events','Day','Temperature']]
# Out:
#   Events       Day  Temperature
# 0   Rain  1/1/2019           32
# 1  Sunny  1/2/2019           35
# 2   Snow  1/3/2019           28
# 3   Snow  1/4/2019           34
# 4   Rain  1/5/2019           31
# 5   Rain  1/6/2019           36
# 6  Sunny  1/7/2019           30

# %%
df['Temperature']
# Out:
# 0    32
# 1    35
# 2    28
# 3    34
# 4    31
# 5    36
# 6    30
# Name: Temperature, dtype: int64

# %%
df['Temperature'].max()
# Out:
# 36

# %%
df.describe()
# Out:
#        Temperature  Windspeed
# count     7.000000   7.000000
# mean     32.285714   5.857143
# std       2.870208   2.410295
# min      28.000000   2.000000
# 25%      30.500000   4.500000
# 50%      32.000000   6.000000
# 75%      34.500000   7.500000
# max      36.000000   9.000000

# %%
df[df.Temperature >=32]
# Out:
#         Day  Temperature  Windspeed Events
# 0  1/1/2019           32          6   Rain
# 1  1/2/2019           35          8  Sunny
# 3  1/4/2019           34          4   Snow
# 5  1/6/2019           36          5   Rain

# %%
df[df.Temperature==df.Temperature.max()]
# Out:
#         Day  Temperature  Windspeed Events
# 5  1/6/2019           36          5   Rain

# %%
df[df.Temperature==df['Temperature'].max()]
# Out:
#         Day  Temperature  Windspeed Events
# 5  1/6/2019           36          5   Rain

# %%
df['Day'][df.Temperature==df['Temperature'].max()]
# Out:
# 5    1/6/2019
# Name: Day, dtype: object

# %%
df[['Day','Temperature']][df.Temperature==df['Temperature'].max()]
# Out:
#         Day  Temperature
# 5  1/6/2019           36

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df
# Out:
#         Day  Temperature  Windspeed Events
# 0  1/1/2019           32          6   Rain
# 1  1/2/2019           35          8  Sunny
# 2  1/3/2019           28          7   Snow
# 3  1/4/2019           34          4   Snow
# 4  1/5/2019           31          2   Rain
# 5  1/6/2019           36          5   Rain
# 6  1/7/2019           30          9  Sunny

# %%
df.set_index('Day')
# Out:
#           Temperature  Windspeed Events
# Day
# 1/1/2019           32          6   Rain
# 1/2/2019           35          8  Sunny
# 1/3/2019           28          7   Snow
# 1/4/2019           34          4   Snow
# 1/5/2019           31          2   Rain
# 1/6/2019           36          5   Rain
# 1/7/2019           30          9  Sunny

# %%
df.set_index('Day', inplace=True)

# %%
df
# Out:
#           Temperature  Windspeed Events
# Day
# 1/1/2019           32          6   Rain
# 1/2/2019           35          8  Sunny
# 1/3/2019           28          7   Snow
# 1/4/2019           34          4   Snow
# 1/5/2019           31          2   Rain
# 1/6/2019           36          5   Rain
# 1/7/2019           30          9  Sunny

# %%
df.loc['1/4/2019']
# Out:
# Temperature      34
# Windspeed         4
# Events         Snow
# Name: 1/4/2019, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#         Day  Temperature  Windspeed Events
# 0  1/1/2019           32          6   Rain
# 1  1/2/2019           35          8  Sunny
# 2  1/3/2019           28          7   Snow
# 3  1/4/2019           34          4   Snow
# 4  1/5/2019           31          2   Rain
# 5  1/6/2019           36          5   Rain
# 6  1/7/2019           30          9  Sunny

# %%
df.set_index('Events', inplace=True)
df
# Out:
#              Day  Temperature  Windspeed
# Events
# Rain    1/1/2019           32          6
# Sunny   1/2/2019           35          8
# Snow    1/3/2019           28          7
# Snow    1/4/2019           34          4
# Rain    1/5/2019           31          2
# Rain    1/6/2019           36          5
# Sunny   1/7/2019           30          9

# %%
df.loc['Snow']
# Out:
#              Day  Temperature  Windspeed
# Events
# Snow    1/3/2019           28          7
# Snow    1/4/2019           34          4

# %%
dt = pd.read_csv("D:\\files\\mydata.csv")
dt
# Out:
#         Date  Year  Length         Title     Subject        Actor  \
# 0   02/10/18  1990   111.0           Tie          Me          Up!
# 1   03/10/18  1991   113.0          High       Heels       Comedy
# 2   04/10/18  1983   104.0          Dead       Zone,          The
# 3   05/10/18  1979   122.0          Cuba      Action     Connery,
# 4   06/10/18  1978    94.0          Days          of       Heaven
# 5   07/10/18  1983   140.0     Octopussy      Action       Moore,
# 6   08/10/18  1984   101.0        Target       Eagle       Action
# 7   09/10/18  1989    99.0      American     Angels:      Baptism
# 8   10/10/18  1985   104.0        Subway       Drama     Lambert,
# 9   11/10/18  1990   149.0       Camille     Claudel        Drama
# 10  12/10/18  1982   188.0         Fanny         and    Alexander
# 11  13/10/18  1982   117.0       Tragedy          of            a
# 12  14/10/18  1966   103.0             A         Man            &
# ...

# %%
dt.describe()
# Out:
#               Year     Length
# count    98.000000   96.00000
# mean   1976.102041  110.62500
# std      15.742444   27.66691
# min    1924.000000   55.00000
# 25%    1966.000000   97.00000
# 50%    1982.000000  104.00000
# 75%    1988.000000  117.25000
# max    1996.000000  286.00000

# %%
dt['Length'].max()
# Out:
# 286.0

# %%
dt['Length'].min()
# Out:
# 55.0

# %%
dt.set_index('Date', inplace=True)

# %%
dt
# Out:
#           Year  Length         Title     Subject        Actor      Actress  \
# Date
# 02/10/18  1990   111.0           Tie          Me          Up!          Tie
# 03/10/18  1991   113.0          High       Heels       Comedy        Bos�,
# 04/10/18  1983   104.0          Dead       Zone,          The       Horror
# 05/10/18  1979   122.0          Cuba      Action     Connery,         Sean
# 06/10/18  1978    94.0          Days          of       Heaven        Drama
# 07/10/18  1983   140.0     Octopussy      Action       Moore,        Roger
# 08/10/18  1984   101.0        Target       Eagle       Action     Connors,
# 09/10/18  1989    99.0      American     Angels:      Baptism           of
# 10/10/18  1985   104.0        Subway       Drama     Lambert,  Christopher
# 11/10/18  1990   149.0       Camille     Claudel        Drama   Depardieu,
# 12/10/18  1982   188.0         Fanny         and    Alexander        Drama
# ...

# %%
dt.reset_index(inplace=True)
#dt[['Date','Year','Length','Title','Actor']]

# %%
nd = dt[['Date','Year','Length','Title','Actor']].head(30)
nd[nd.Year >=1990]
# Out:
#         Date  Year  Length     Title   Actor
# 0   02/10/18  1990   111.0       Tie     Up!
# 1   03/10/18  1991   113.0      High  Comedy
# 9   11/10/18  1990   149.0   Camille   Drama
# 23  25/10/18  1991   105.0  Predator  Action
# 25  27/10/18  1990    97.0  Zandalee   Cage,
